# %%
from matplotlib import font_manager
 
for font in font_manager.fontManager.ttflist:
    # 查看字体名以及对应的字体文件名
    print(font.name, '-', font.fname)
# Out:
# DejaVu Serif - /Users/xingyan/.conda/envs/dgl/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf
# STIXNonUnicode - /Users/xingyan/.conda/envs/dgl/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf
# STIXSizeFourSym - /Users/xingyan/.conda/envs/dgl/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf
# STIXSizeThreeSym - /Users/xingyan/.conda/envs/dgl/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf
# DejaVu Sans Mono - /Users/xingyan/.conda/envs/dgl/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf
# cmsy10 - /Users/xingyan/.conda/envs/dgl/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf
# cmb10 - /Users/xingyan/.conda/envs/dgl/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
# DejaVu Sans - /Users/xingyan/.conda/envs/dgl/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf
# ...

# %%
# the directories that store the .ttf files (macOS)
path0 = "/Users/xingyan/.conda/envs/dgl/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/"
path = "/System/Library/Fonts/Supplemental/"

# %% [markdown]
# ## find the corresponding font-name

# %%
# find the corresponding font-name 

fname = "Bradley Hand Bold"
for font in font_manager.fontManager.ttflist:
    if fname in font.fname:
        print(font.name, '-', font.fname)
# Out:
# Bradley Hand - /System/Library/Fonts/Supplemental/Bradley Hand Bold.ttf

# %% [markdown]
# ## Set or regester your own font

# %%
from matplotlib import pyplot as plt

# the default setting
plt.text(0.5, 0.5, "1024", ha='center', fontsize=50)
# Out:
# Text(0.5, 0.5, '1024')

# %%
# regester your own font
# font_manager.fontManager.addfont("/System/Library/Fonts/Supplemental/Bradley Hand Bold.ttf")

plt.rcParams['font.family'] = "Bradley Hand"
plt.text(0.5, 0.5, "1024", ha='center', fontsize=100)
# Out:
# Text(0.5, 0.5, '1024')
